# %%
# dependencies and setup
import pandas as pd

# files to load
file1 = "Raw_Data/IMDB movies.csv"
file2 = "Raw_Data/rotten tomato movie reviwe.csv"

# read files and store into pandas dataframe
IMDB_movies = pd.read_csv(file1, low_memory=False)
rotten_tomatoes = pd.read_csv(file2, low_memory=False)

# %%
# view IMDB_movies dataframe
IMDB_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     12/26/1906    Biography, Crime, Drama        70         Australia
# 2  1911      8/19/1911                      Drama        53  Germany, Denmark
# 3  1912     11/13/1912             Drama, History       100               USA
# 4  1911       3/6/1911  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes    budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154       NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $2,250
# 2  Two men of high rank are both wooing the beaut...      5.8   188       NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $45,000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237       NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
# rename IMDB avg_vote to ratings
IMDB_movies = IMDB_movies.rename(columns={"avg_vote":"IMBD Ratings"})
IMDB_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     12/26/1906    Biography, Crime, Drama        70         Australia
# 2  1911      8/19/1911                      Drama        53  Germany, Denmark
# 3  1912     11/13/1912             Drama, History       100               USA
# 4  1911       3/6/1911  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description IMBD Ratings votes  \
# 0  The adventures of a female reporter in the 1890s.          5.9   154
# 1  True story of notorious Australian outlaw Ned ...          6.1   589
# 2  Two men of high rank are both wooing the beaut...          5.8   188
# 3  The fabled queen of Egypt's affair with Roman ...          5.2   446
# 4  Loosely adapted from Dante's Divine Comedy and...          7.0  2237
#
#      budget  usa_gross_income worlwide_gross_income metascore  \
# 0       NaN               NaN                   NaN       NaN
# 1   $2,250                NaN                   NaN       NaN
# 2       NaN               NaN                   NaN       NaN
# 3  $45,000                NaN                   NaN       NaN
# 4       NaN               NaN                   NaN       NaN
#
#   reviews_from_users  reviews_from_critics
# 0                1.0                   2.0
# 1                7.0                   7.0
# 2                5.0                   2.0
# 3               25.0                   3.0
# 4               31.0                  14.0
#
# [5 rows x 22 columns]

# %%
# remove metascore, reviews_from_users, and reviews_from_critics from IMDB
IMDB_movies = IMDB_movies.drop(columns=['metascore', 'reviews_from_users', 'reviews_from_critics'])
IMDB_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     12/26/1906    Biography, Crime, Drama        70         Australia
# 2  1911      8/19/1911                      Drama        53  Germany, Denmark
# 3  1912     11/13/1912             Drama, History       100               USA
# 4  1911       3/6/1911  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# 0     None                      Alexander Black
# 1     None                         Charles Tait
# 2      NaN                            Urban Gad
# 3  English                   Charles L. Gaskill
# 4  Italian  Francesco Bertolini, Adolfo Padovan
#
#                                   writer             production_company  \
# 0                        Alexander Black     Alexander Black Photoplays
# 1                           Charles Tait                 J. and N. Tait
# 2  Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 3                       Victorien Sardou  Helen Gardner Picture Players
# 4                        Dante Alighieri                    Milano Film
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description  IMBD Ratings  votes  \
# 0  The adventures of a female reporter in the 1890s.           5.9    154
# 1  True story of notorious Australian outlaw Ned ...           6.1    589
# 2  Two men of high rank are both wooing the beaut...           5.8    188
# 3  The fabled queen of Egypt's affair with Roman ...           5.2    446
# 4  Loosely adapted from Dante's Divine Comedy and...           7.0   2237
#
#      budget usa_gross_income worlwide_gross_income
# 0       NaN              NaN                   NaN
# 1   $2,250               NaN                   NaN
# 2       NaN              NaN                   NaN
# 3  $45,000               NaN                   NaN
# 4       NaN              NaN                   NaN

# %%
# clean up IMDB column names
IMDB_movies = IMDB_movies.rename(columns={"imdb_title_id":"IMDB Title ID", "title":"Title", "original_title":"Original Title", "year":"Year", "date_published":"Date Published", "genre": "Genre", "duration":"Duration", "country":"Country", "language":"Language", "director":"Director", "writer":"Writer", "production_company":"Production Company", "actors":"Actors", "description":"Description", "votes":"Votes", "budget":"Budget", "usa_gross_income":"Gross Income: USA", "worlwide_gross_income":"Gross Income: Worldwide"})
IMDB_movies.head()
# Out:
#   IMDB Title ID                        Title               Original Title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    Year Date Published                      Genre  Duration           Country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     12/26/1906    Biography, Crime, Drama        70         Australia
# 2  1911      8/19/1911                      Drama        53  Germany, Denmark
# 3  1912     11/13/1912             Drama, History       100               USA
# 4  1911       3/6/1911  Adventure, Drama, Fantasy        68             Italy
#
#   Language                             Director  \
# 0     None                      Alexander Black
# 1     None                         Charles Tait
# 2      NaN                            Urban Gad
# 3  English                   Charles L. Gaskill
# 4  Italian  Francesco Bertolini, Adolfo Padovan
#
#                                   Writer             Production Company  \
# 0                        Alexander Black     Alexander Black Photoplays
# 1                           Charles Tait                 J. and N. Tait
# 2  Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 3                       Victorien Sardou  Helen Gardner Picture Players
# 4                        Dante Alighieri                    Milano Film
#
#                                               Actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          Description  IMBD Ratings  Votes  \
# 0  The adventures of a female reporter in the 1890s.           5.9    154
# 1  True story of notorious Australian outlaw Ned ...           6.1    589
# 2  Two men of high rank are both wooing the beaut...           5.8    188
# 3  The fabled queen of Egypt's affair with Roman ...           5.2    446
# 4  Loosely adapted from Dante's Divine Comedy and...           7.0   2237
#
#      Budget Gross Income: USA Gross Income: Worldwide
# 0       NaN               NaN                     NaN
# 1   $2,250                NaN                     NaN
# 2       NaN               NaN                     NaN
# 3  $45,000                NaN                     NaN
# 4       NaN               NaN                     NaN

# %%
# view Rotten Tomatoes dataframe
rotten_tomatoes.head()
# Out:
#                               Name  \
# 0          The Angry Birds Movie 2
# 1  Legend Of The Demon Cat (Kûkai)
# 2   Dora and the Lost City of Gold
# 3                             Luce
# 4                        Good Boys
#
#                                               Rating        Directed By  \
# 0                     PG (for rude humor and action)   Thurop Van Orman
# 1                                                 NR         Kaige Chen
# 2            PG (for action and some impolite humor)        James Bobin
# 3   R (for language throughout, sexual content, n...        Julius Onah
# 4   R (for strong crude sexual content, drug and ...    Gene Stupnitsky
#
#               Runtime                 Studio TOMATOMETER score  \
# 0     100 minutes        Columbia Pictures             73%
# 1     129 minutes              Well Go USA             91%
# 2     102 minutes       Paramount Pictures             84%
# 3     109 minutes                     NEON             91%
# 4      95 minutes       Universal Pictures             80%
#
#    TOMATOMETER Count AUDIENCE score AUDIENCE count
# 0                107        84%              4,023
# 1                 11        37%                 74
# 2                148        88%              6,715
# 3                151        77%                284
# 4                237        86%             13,007

# %%
# rename Rotten Tomatoes columns
rotten_tomatoes = rotten_tomatoes.rename(columns={"Name":"Title", "Directed By":"Director"})
rotten_tomatoes.head()
# Out:
#                              Title  \
# 0          The Angry Birds Movie 2
# 1  Legend Of The Demon Cat (Kûkai)
# 2   Dora and the Lost City of Gold
# 3                             Luce
# 4                        Good Boys
#
#                                               Rating           Director  \
# 0                     PG (for rude humor and action)   Thurop Van Orman
# 1                                                 NR         Kaige Chen
# 2            PG (for action and some impolite humor)        James Bobin
# 3   R (for language throughout, sexual content, n...        Julius Onah
# 4   R (for strong crude sexual content, drug and ...    Gene Stupnitsky
#
#               Runtime                 Studio TOMATOMETER score  \
# 0     100 minutes        Columbia Pictures             73%
# 1     129 minutes              Well Go USA             91%
# 2     102 minutes       Paramount Pictures             84%
# 3     109 minutes                     NEON             91%
# 4      95 minutes       Universal Pictures             80%
#
#    TOMATOMETER Count AUDIENCE score AUDIENCE count
# 0                107        84%              4,023
# 1                 11        37%                 74
# 2                148        88%              6,715
# 3                151        77%                284
# 4                237        86%             13,007

# %%
IMDB_movies.to_csv("Raw_Data/updated_IMDB.csv", index=False, header=True)
rotten_tomatoes.to_csv("Raw_Data/updated_rotten_tomatoes.csv", index=False, header=True)
