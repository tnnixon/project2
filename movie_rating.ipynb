# %%
import pandas as pd 
import os

# %%
imdb_DF = pd.read_csv('Raw_Data/IMDb movies.csv')
tomato_DF = pd.read_csv('Raw_Data/rotten tomato movie reviwe.csv')
# Out:
# C:\Users\Hannah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
imdb_DF.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
tomato_DF.head()
# Out:
#                               Name  \
# 0          The Angry Birds Movie 2
# 1  Legend Of The Demon Cat (Kûkai)
# 2   Dora and the Lost City of Gold
# 3                             Luce
# 4                        Good Boys
#
#                                               Rating        Directed By  \
# 0                     PG (for rude humor and action)   Thurop Van Orman
# 1                                                 NR         Kaige Chen
# 2            PG (for action and some impolite humor)        James Bobin
# 3   R (for language throughout, sexual content, n...        Julius Onah
# 4   R (for strong crude sexual content, drug and ...    Gene Stupnitsky
#
#               Runtime                 Studio TOMATOMETER score  \
# 0     100 minutes        Columbia Pictures             73%
# 1     129 minutes              Well Go USA             91%
# 2     102 minutes       Paramount Pictures             84%
# 3     109 minutes                     NEON             91%
# 4      95 minutes       Universal Pictures             80%
#
#    TOMATOMETER Count AUDIENCE score AUDIENCE count
# 0                107        84%              4,023
# 1                 11        37%                 74
# 2                148        88%              6,715
# 3                151        77%                284
# 4                237        86%             13,007

# %%
print(len(imdb_DF))
print(len(tomato_DF))
# Out:
# 85855
# 2100

# %%
mod_imdb = imdb_DF.drop(columns = ['metascore', 'reviews_from_users','reviews_from_critics'])

# %%
#rename col to join 
tomato_DF = tomato_DF.rename(columns = {'Name':'title','Directed By':'director' })

# %%
# remove the 
mod_tom = tomato_DF['director'].str.strip()
tomato_DF['director']=mod_tom

# %%
join = mod_imdb.merge(tomato_DF, how="left", left_on= ['title','director'], right_on=['title','director'])
join.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...   budget  \
# 0     None                      Alexander Black  ...      NaN
# 1     None                         Charles Tait  ...   $ 2250
# 2      NaN                            Urban Gad  ...      NaN
# 3  English                   Charles L. Gaskill  ...  $ 45000
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...      NaN
#
#   usa_gross_income worlwide_gross_income Rating  Runtime  Studio  \
# 0              NaN                   NaN    NaN      NaN     NaN
# 1              NaN                   NaN    NaN      NaN     NaN
# 2              NaN                   NaN    NaN      NaN     NaN
# 3              NaN                   NaN    NaN      NaN     NaN
# 4              NaN                   NaN    NaN      NaN     NaN
#
#   TOMATOMETER score TOMATOMETER Count AUDIENCE score AUDIENCE count
# 0               NaN               NaN            NaN            NaN
# 1               NaN               NaN            NaN            NaN
# 2               NaN               NaN            NaN            NaN
# 3               NaN               NaN            NaN            NaN
# 4               NaN               NaN            NaN            NaN
#
# [5 rows x 26 columns]

# %%
len(join)
# Out:
# 85855

# %%
join.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'Rating',
#        'Runtime', 'Studio', 'TOMATOMETER score', 'TOMATOMETER Count',
#        'AUDIENCE score', 'AUDIENCE count'],
#       dtype='object')

# %%
a = join.loc[join["title"]=="A Star Is Born"]
a
# Out:
#       imdb_title_id           title  original_title  year date_published  \
# 58932     tt1517451  A Star Is Born  A Star Is Born  2018     2018-10-11
#
#                        genre  duration country language        director  ...  \
# 58932  Drama, Music, Romance       136     USA  English  Bradley Cooper  ...
#
#            budget usa_gross_income worlwide_gross_income  \
# 58932  $ 36000000      $ 215288866           $ 436188866
#
#                                                   Rating             Runtime  \
# 58932   R (for language throughout, some sexuality/nu...     135 minutes
#
#                          Studio TOMATOMETER score TOMATOMETER Count  \
# 58932   Warner Bros. Pictures             90%                 501.0
#
#       AUDIENCE score AUDIENCE count
# 58932        79%             20,023
#
# [1 rows x 26 columns]

# %%
b = tomato_DF.loc[tomato_DF['title']=='A Star Is Born']
b1 = b.iloc[0]['director']
b1
# Out:
# ' Bradley Cooper'

# %%
c = imdb_DF.loc[imdb_DF['title']=='A Star Is Born']
c1= c.iloc[0]['director']
c1
# Out:
# 'Bradley Cooper'

# %%
d = c1 == b1
d
# Out:
# False
