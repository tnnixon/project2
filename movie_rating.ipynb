# %%
import pandas as pd 
import os

# %%
imdb_DF = pd.read_csv('Raw_Data/IMDb movies.csv')
tomato_DF = pd.read_csv('Raw_Data/rotten tomato movie reviwe.csv')
# Out:
# C:\Users\Hannah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
imdb_DF.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
tomato_DF.head()
# Out:
#                               Name  \
# 0          The Angry Birds Movie 2
# 1  Legend Of The Demon Cat (Kûkai)
# 2   Dora and the Lost City of Gold
# 3                             Luce
# 4                        Good Boys
#
#                                               Rating        Directed By  \
# 0                     PG (for rude humor and action)   Thurop Van Orman
# 1                                                 NR         Kaige Chen
# 2            PG (for action and some impolite humor)        James Bobin
# 3   R (for language throughout, sexual content, n...        Julius Onah
# 4   R (for strong crude sexual content, drug and ...    Gene Stupnitsky
#
#               Runtime                 Studio TOMATOMETER score  \
# 0     100 minutes        Columbia Pictures             73%
# 1     129 minutes              Well Go USA             91%
# 2     102 minutes       Paramount Pictures             84%
# 3     109 minutes                     NEON             91%
# 4      95 minutes       Universal Pictures             80%
#
#    TOMATOMETER Count AUDIENCE score AUDIENCE count
# 0                107        84%              4,023
# 1                 11        37%                 74
# 2                148        88%              6,715
# 3                151        77%                284
# 4                237        86%             13,007

# %%
print(len(imdb_DF))
print(len(tomato_DF))
# Out:
# 85855
# 2100

# %%
mod_imdb = imdb_DF.drop(columns = ['metascore', 'reviews_from_users','reviews_from_critics'])

# %%
#rename col to join 
tomato_DF = tomato_DF.rename(columns = {'Name':'title','Directed By':'director' })

# %%
# remove the leading and ending spaces 
mod_tom = tomato_DF['director'].str.strip()
tomato_DF['director']=mod_tom

# %%
join = tomato_DF.merge(mod_imdb, how="left", left_on= ['title','director'], right_on=['original_title','director'])
join.head()
# Out:
#                            title_x  \
# 0          The Angry Birds Movie 2
# 1  Legend Of The Demon Cat (Kûkai)
# 2   Dora and the Lost City of Gold
# 3                             Luce
# 4                        Good Boys
#
#                                               Rating          director  \
# 0                     PG (for rude humor and action)  Thurop Van Orman
# 1                                                 NR        Kaige Chen
# 2            PG (for action and some impolite humor)       James Bobin
# 3   R (for language throughout, sexual content, n...       Julius Onah
# 4   R (for strong crude sexual content, drug and ...   Gene Stupnitsky
#
#               Runtime                 Studio TOMATOMETER score  \
# 0     100 minutes        Columbia Pictures             73%
# 1     129 minutes              Well Go USA             91%
# 2     102 minutes       Paramount Pictures             84%
# 3     109 minutes                     NEON             91%
# 4      95 minutes       Universal Pictures             80%
#
#    TOMATOMETER Count AUDIENCE score AUDIENCE count imdb_title_id  ...  \
# 0                107        84%              4,023           NaN  ...
# 1                 11        37%                 74           NaN  ...
# 2                148        88%              6,715     tt7547410  ...
# 3                151        77%                284     tt7616148  ...
# 4                237        86%             13,007     tt7343762  ...
#
#                     language                              writer  \
# 0                        NaN                                 NaN
# 1                        NaN                                 NaN
# 2  English, Spanish, Quechua  Nicholas Stoller, Matthew Robinson
# 3                    English               J.C. Lee, Julius Onah
# 4                    English      Lee Eisenberg, Gene Stupnitsky
#
#     production_company                                             actors  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2    Paramount Players  Benicio Del Toro, Madelyn Miranda, Dee Bradley...
# 3  Dream Factory Group  Naomi Watts, Octavia Spencer, Kelvin Harrison ...
# 4        Good Universe  Jacob Tremblay, Keith L. Williams, Brady Noon,...
#
#                                          description  avg_vote    votes  \
# 0                                                NaN       NaN      NaN
# 1                                                NaN       NaN      NaN
# 2  Dora, a teenage explorer, leads her friends on...       6.1  21413.0
# 3  A married couple is forced to reckon with thei...       6.7   8668.0
# 4  Three 6th grade boys ditch school and embark o...       6.7  55929.0
#
#        budget usa_gross_income worlwide_gross_income
# 0         NaN              NaN                   NaN
# 1         NaN              NaN                   NaN
# 2  $ 49000000       $ 60477943           $ 119682635
# 3         NaN        $ 2010613             $ 2268204
# 4  $ 20000000       $ 83140306           $ 111037232
#
# [5 rows x 27 columns]

# %%
len(join)
# Out:
# 2100

# %%
join.columns
# Out:
# Index(['title_x', 'Rating', 'director', 'Runtime', 'Studio',
#        'TOMATOMETER score', 'TOMATOMETER Count', 'AUDIENCE score',
#        'AUDIENCE count', 'imdb_title_id', 'title_y', 'original_title', 'year',
#        'date_published', 'genre', 'duration', 'country', 'language', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income'],
#       dtype='object')

# %%
a = join.loc[join["title"]=="A Star Is Born"]
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-83840f9f75b9> in <module>
# ----> 1 a = join.loc[join["title"]=="A Star Is Born"]
#       2 a
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'title'

# %%
b = tomato_DF.loc[tomato_DF['title']=='A Star Is Born']
b1 = b.iloc[0]['director']
b1
# Out:
# 'Bradley Cooper'

# %%
c = imdb_DF.loc[imdb_DF['title']=='A Star Is Born']
c1= c.iloc[0]['director']
c1
# Out:
# 'Bradley Cooper'

# %%
d = c1 == b1
d
# Out:
# True

# %%
x= imdb_DF.loc[imdb_DF['title']=='Bakemono No Ko']
x
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description, avg_vote, votes, budget, usa_gross_income, worlwide_gross_income, metascore, reviews_from_users, reviews_from_critics]
# Index: []
#
# [0 rows x 22 columns]

# %%
df = join.loc[join['avg_vote'].isnull()]
df
# Out:
#                                        title  \
# 0                    The Angry Birds Movie 2
# 1            Legend Of The Demon Cat (Kûkai)
# 2             Dora and the Lost City of Gold
# 4                                  Good Boys
# 5                               Danger Close
# ...                                      ...
# 2095  The Boy And The Beast (Bakemono No Ko)
# 2096              The Other Side of the Door
# 2097                       Touched With Fire
# 2098                   The Funhouse Massacre
# 2099                          A War (Krigen)
#
#                                                  Rating  \
# 0                        PG (for rude humor and action)
# 1                                                    NR
# 2               PG (for action and some impolite humor)
# 4      R (for strong crude sexual content, drug and ...
# 5      R (for sequences of war violence, and languag...
# ...                                                 ...
# 2095   R (for strong combat violence throughout, blo...
# 2096   R (for strong sexual content, graphic nudity ...
# 2097          R (for violence and language throughout.)
# 2098         R (for language and some violence/torture)
# 2099            PG-13 (for some violence and language.)
#
#                             director             Runtime  \
# 0                   Thurop Van Orman     100 minutes
# 1                         Kaige Chen     129 minutes
# 2                        James Bobin     102 minutes
# 4                    Gene Stupnitsky      95 minutes
# 5                      Kriv Stenders     118 minutes
# ...                              ...                 ...
# 2095                     Michael Bay     144 minutes
# 2096  Charlie Kaufman,  Duke Johnson      96 minutes
# 2097                    Paco Cabezas      90 minutes
# 2098            Florian Gallenberger     110 minutes
# 2099                   Mamoru Hosoda     119 minutes
#
#                            Studio TOMATOMETER score  TOMATOMETER Count  \
# 0             Columbia Pictures             73%                    107
# 1                   Well Go USA             91%                     11
# 2            Paramount Pictures             84%                    148
# 4            Universal Pictures             80%                    237
# 5                   Saban Films             67%                     30
# ...                           ...               ...                ...
# 2095         Paramount Pictures             51%                     67
# 2096       Starburns Industries             92%                     37
# 2097        Circle of Confusion             44%                     50
# 2098    Majestic Filmproduktion             26%                     14
# 2099   FUNimation Entertainment             90%                     92
#
#      AUDIENCE score AUDIENCE count imdb_title_id  ... language writer  \
# 0           84%              4,023           NaN  ...      NaN    NaN
# 1           37%                 74           NaN  ...      NaN    NaN
# 2           88%              6,715           NaN  ...      NaN    NaN
# 4           86%             13,007           NaN  ...      NaN    NaN
# 5           67%                 90           NaN  ...      NaN    NaN
# ...             ...            ...           ...  ...      ...    ...
# 2095        82%             33,491           NaN  ...      NaN    NaN
# 2096        71%             19,600           NaN  ...      NaN    NaN
# 2097        55%              6,208           NaN  ...      NaN    NaN
# 2098        61%              3,914           NaN  ...      NaN    NaN
# 2099        88%              2,982           NaN  ...      NaN    NaN
#
#      production_company actors  description avg_vote votes budget  \
# 0                   NaN    NaN          NaN      NaN   NaN    NaN
# 1                   NaN    NaN          NaN      NaN   NaN    NaN
# 2                   NaN    NaN          NaN      NaN   NaN    NaN
# 4                   NaN    NaN          NaN      NaN   NaN    NaN
# 5                   NaN    NaN          NaN      NaN   NaN    NaN
# ...                 ...    ...          ...      ...   ...    ...
# 2095                NaN    NaN          NaN      NaN   NaN    NaN
# 2096                NaN    NaN          NaN      NaN   NaN    NaN
# 2097                NaN    NaN          NaN      NaN   NaN    NaN
# 2098                NaN    NaN          NaN      NaN   NaN    NaN
# 2099                NaN    NaN          NaN      NaN   NaN    NaN
#
#      usa_gross_income worlwide_gross_income
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 4                 NaN                   NaN
# 5                 NaN                   NaN
# ...               ...                   ...
# 2095              NaN                   NaN
# 2096              NaN                   NaN
# 2097              NaN                   NaN
# 2098              NaN                   NaN
# 2099              NaN                   NaN
#
# [1566 rows x 26 columns]
