# %%
import pandas as pd 
import os 
import datetime as dt

# %%
imdb_DF = pd.read_csv('Raw_Data/IMDb movies.csv')
tomato_DF = pd.read_csv('Raw_Data/rotten_tomatoes_movies.csv')
# Out:
# C:\Users\Hannah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
imdb_DF.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
tomato_DF.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
# 1  Nicole Holofcener's newest might seem slight i...              R
# 2  Blake Edwards' bawdy comedy may not score a pe...              R
# 3  Sidney Lumet's feature debut is a superbly wri...             NR
# 4  One of Disney's finest live-action adventures,...              G
#
#                                               genres          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors original_release_date  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...            2010-02-12
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...            2010-04-30
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...            1979-10-05
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...            1954-01-01
#
#    ...      production_company  tomatometer_status tomatometer_rating  \
# 0  ...        20th Century Fox              Rotten               49.0
# 1  ...  Sony Pictures Classics     Certified-Fresh               87.0
# 2  ...             Waner Bros.               Fresh               67.0
# 3  ...    Criterion Collection     Certified-Fresh              100.0
# 4  ...                  Disney               Fresh               89.0
#
#   tomatometer_count  audience_status  audience_rating audience_count  \
# 0             149.0          Spilled             53.0       254421.0
# 1             142.0          Upright             64.0        11574.0
# 2              24.0          Spilled             53.0        14684.0
# 3              54.0          Upright             97.0       105386.0
# 4              27.0          Upright             74.0        68918.0
#
#    tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                             43                               73
# 1                             44                              123
# 2                              2                               16
# 3                              6                               54
# 4                              5                               24
#
#    tomatometer_rotten_critics_count
# 0                                76
# 1                                19
# 2                                 8
# 3                                 0
# 4                                 3
#
# [5 rows x 22 columns]

# %%
print(len(imdb_DF))
print(len(tomato_DF))
# Out:
# 85855
# 17712

# %%
a = mod_imdb['year'].unique()

# %%
b = tomato_DF['year'].unique()

# %%
a.sort()
print(a)
# Out:
# ['1894' '1906' '1911' '1912' '1913' '1914' '1915' '1916' '1917' '1918'
#  '1919' '1920' '1921' '1922' '1923' '1924' '1925' '1926' '1927' '1928'
#  '1929' '1930' '1931' '1932' '1933' '1934' '1935' '1936' '1937' '1938'
#  '1939' '1940' '1941' '1942' '1943' '1944' '1945' '1946' '1947' '1948'
#  '1949' '1950' '1951' '1952' '1953' '1954' '1955' '1956' '1957' '1958'
#  '1959' '1960' '1961' '1962' '1963' '1964' '1965' '1966' '1967' '1968'
#  '1969' '1970' '1971' '1972' '1973' '1974' '1975' '1976' '1977' '1978'
#  '1979' '1980' '1981' '1982' '1983' '1984' '1985' '1986' '1987' '1988'
#  '1989' '1990' '1991' '1992' '1993' '1994' '1995' '1996' '1997' '1998'
#  '1999' '2000' '2001' '2002' '2003' '2004' '2005' '2006' '2007' '2008'
#  '2009' '2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018'
#  '2019' '2020' 'TV Movie 2019']

# %%
b.sort()
print(b)
# Out:
# ['1914' '1915' '1916' '1919' '1920' '1921' '1922' '1923' '1924' '1925'
#  '1926' '1927' '1928' '1929' '1930' '1931' '1932' '1933' '1934' '1935'
#  '1936' '1937' '1938' '1939' '1940' '1941' '1942' '1943' '1944' '1945'
#  '1946' '1947' '1948' '1949' '1950' '1951' '1952' '1953' '1954' '1955'
#  '1956' '1957' '1958' '1959' '1960' '1961' '1962' '1963' '1964' '1965'
#  '1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974' '1975'
#  '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984' '1985'
#  '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994' '1995'
#  '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004' '2005'
#  '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015'
#  '2016' '2017' '2018' '2019' '2020' 'nan']

# %%
a[5:]==b[]

# %%
mod_imdb = imdb_DF.drop(columns=['metascore', 'reviews_from_users','reviews_from_critics'])
mod_imdb['year']=mod_imdb['year'].astype(str)

# %%
#rename col to join 
tomato_DF = tomato_DF.rename(columns = {'movie_title':'title','directors':'director' })

# %%
# remove the leading and ending spaces 
#mod_tom = tomato_DF['director'].str.strip()
#tomato_DF['director']=mod_tom
tomato_DF.dtypes
# Out:
# rotten_tomatoes_link                 object
# title                                object
# movie_info                           object
# critics_consensus                    object
# content_rating                       object
# genres                               object
# director                             object
# authors                              object
# actors                               object
# original_release_date                object
# streaming_release_date               object
# runtime                             float64
# production_company                   object
# tomatometer_status                   object
# tomatometer_rating                  float64
# tomatometer_count                   float64
# audience_status                      object
# audience_rating                     float64
# audience_count                      float64
# tomatometer_top_critics_count         int64
# tomatometer_fresh_critics_count       int64
# tomatometer_rotten_critics_count      int64
# year                                 object
# dtype: object

# %%
tomato_DF['year']=pd.DatetimeIndex(tomato_DF['original_release_date']).year
tomato_DF['year'] = tomato_DF['year'].astype(str).replace('\.0','',regex=True)
tomato_DF.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                                title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
# 1  Nicole Holofcener's newest might seem slight i...              R
# 2  Blake Edwards' bawdy comedy may not score a pe...              R
# 3  Sidney Lumet's feature debut is a superbly wri...             NR
# 4  One of Disney's finest live-action adventures,...              G
#
#                                               genres           director  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors original_release_date  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...            2010-02-12
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...            2010-04-30
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...            1979-10-05
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...            1954-01-01
#
#    ... tomatometer_status  tomatometer_rating tomatometer_count  \
# 0  ...             Rotten                49.0             149.0
# 1  ...    Certified-Fresh                87.0             142.0
# 2  ...              Fresh                67.0              24.0
# 3  ...    Certified-Fresh               100.0              54.0
# 4  ...              Fresh                89.0              27.0
#
#   audience_status  audience_rating  audience_count  \
# 0         Spilled             53.0        254421.0
# 1         Upright             64.0         11574.0
# 2         Spilled             53.0         14684.0
# 3         Upright             97.0        105386.0
# 4         Upright             74.0         68918.0
#
#   tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                            43                               73
# 1                            44                              123
# 2                             2                               16
# 3                             6                               54
# 4                             5                               24
#
#    tomatometer_rotten_critics_count  year
# 0                                76  2010
# 1                                19  2010
# 2                                 8  1979
# 3                                 0  1957
# 4                                 3  1954
#
# [5 rows x 23 columns]

# %%
join2 = tomato_DF.merge(imdb_DF, how="inner", left_on= ['year','title'], right_on=['year','original_title'])
join2.head()
# Out:
#   rotten_tomatoes_link          title_x  \
# 0    m/10_minutes_gone  10 Minutes Gone
# 1              m/10x10            10x10
# 2         m/14_cameras       14 Cameras
# 3          m/1922_2017             1922
# 4          m/1985_2018             1985
#
#                                           movie_info  \
# 0  A man loses his memory after a bank heist goes...
# 1  Lewis, an outwardly ordinary guy, kidnaps a wo...
# 2  When a family of four rent a beautiful house f...
# 3  A rancher conspires to murder his wife for fin...
# 4  A man decides to return to his hometown in Tex...
#
#                                    critics_consensus content_rating  \
# 0                                                NaN              R
# 1                                                NaN             NR
# 2                                                NaN             NR
# 3  Thanks to director Zak Hilditch's patient stor...             NR
# 4  1985 pays tribute to a generation of lost live...             NR
#
#                                    genres                  director_x  \
# 0  Action & Adventure, Mystery & Suspense             Brian A. Miller
# 1                      Mystery & Suspense                  Suzi Ewing
# 2                                  Horror  Seth Fuller, Scott Hussion
# 3               Drama, Mystery & Suspense                Zak Hilditch
# 4                                   Drama                     Yen Tan
#
#                               authors  \
# 0             Kelvin Mao, Jeff Jingle
# 1                         Noel Clarke
# 2                      Victor Zarcoff
# 3                        Zak Hilditch
# 4  Yen Tan, Leslie "Hutch" Hutchinson
#
#                                             actors_x original_release_date  \
# 0  Michael Chiklis, Bruce Willis, Meadow Williams...            2019-09-27
# 1  Luke Evans, Kelly Reilly, Noel Clarke, Jason M...            2018-04-13
# 2  Amber Midthunder, Tait Fletcher, Sharon Anne H...            2018-07-27
# 3  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...            2017-10-20
# 4  Jamie Chung, Michael Chiklis, Virginia Madsen,...            2018-10-26
#
#    ...                                           actors_y  \
# 0  ...  Bruce Willis, Michael Chiklis, Meadow Williams...
# 1  ...  Kelly Reilly, Luke Evans, Noel Clarke, Olivia ...
# 2  ...  Zach Dulin, Kodi Saint Angelo, Neville Archamb...
# 3  ...  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 4  ...  Cory Michael Smith, Virginia Madsen, Michael C...
#
#                                          description avg_vote  votes  budget  \
# 0  A crime thriller that centers on a man whose m...      3.6   2221     NaN
# 1  A man abducts a flower shop owner and holds he...      5.0   7007     NaN
# 2  When a family of five rent a beautiful house f...      4.5   2313     NaN
# 3  A simple yet proud farmer in the year 1922 con...      6.3  49788     NaN
# 4  A closeted young man goes home for the holiday...      7.0   1696     NaN
#
#    usa_gross_income worlwide_gross_income  metascore  reviews_from_users  \
# 0               NaN              $ 323989       13.0               104.0
# 1            $ 2263               $ 68260        NaN                82.0
# 2               NaN                   NaN       25.0                46.0
# 3               NaN                   NaN       70.0               216.0
# 4               NaN               $ 25013       71.0                24.0
#
#    reviews_from_critics
# 0                  21.0
# 1                  36.0
# 2                  13.0
# 3                  67.0
# 4                  43.0
#
# [5 rows x 44 columns]

# %%
len(join2)
# Out:
# 1460

# %%
join2.columns
# Out:
# Index(['rotten_tomatoes_link', 'title_x', 'movie_info', 'critics_consensus',
#        'content_rating', 'genres', 'director_x', 'authors', 'actors_x',
#        'original_release_date', 'streaming_release_date', 'runtime',
#        'production_company_x', 'tomatometer_status', 'tomatometer_rating',
#        'tomatometer_count', 'audience_status', 'audience_rating',
#        'audience_count', 'tomatometer_top_critics_count',
#        'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count',
#        'year', 'imdb_title_id', 'title_y', 'original_title', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director_y', 'writer',
#        'production_company_y', 'actors_y', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
b = tomato_DF.loc[tomato_DF['title']=='Cleopatra']
b.iloc[0]['year']
# Out:
# '1963'

# %%
c = imdb_DF.loc[imdb_DF['title']=='Cleopatra']
c.iloc[3]['year']
# Out:
# 1963

# %%
d = join2.loc[join2['title_x']=='Cleopatra'] 
d
# Out:
# Empty DataFrame
# Columns: [rotten_tomatoes_link, title_x, movie_info, critics_consensus, content_rating, genres, director_x, authors, actors_x, original_release_date, streaming_release_date, runtime, production_company_x, tomatometer_status, tomatometer_rating, tomatometer_count, audience_status, audience_rating, audience_count, tomatometer_top_critics_count, tomatometer_fresh_critics_count, tomatometer_rotten_critics_count, year, imdb_title_id, title_y, original_title, date_published, genre, duration, country, language, director_y, writer, production_company_y, actors_y, description, avg_vote, votes, budget, usa_gross_income, worlwide_gross_income, metascore, reviews_from_users, reviews_from_critics]
# Index: []
#
# [0 rows x 44 columns]

# %%
join2['year'].unique()
# Out:
# array(['2019', '2018', '2017', '2013', '2014', '2016', '2015', '2020',
#        '2012'], dtype=object)

# %%
df2 = join2.dropna(subset =['avg_vote'])
len(df2)
# Out:
# 1460

# %%
df = join2.loc[join2['avg_vote'].isnull()]
df.head()
# Out:
#                      rotten_tomatoes_link                          title_x  \
# 3                  m/1000013-12_angry_men  12 Angry Men (Twelve Angry Men)
# 4   m/1000079-20000_leagues_under_the_sea     20,000 Leagues Under The Sea
# 5                              m/10000_bc                      10,000 B.C.
# 10                      m/10002008-charly        Charly (A Heartbeat Away)
# 22                     m/10002673-prowler    The Prowler (Cost of Living )
#
#                                            movie_info  \
# 3   Following the closing arguments in a murder tr...
# 4   In 1866, Professor Pierre M. Aronnax (Paul Luk...
# 5   Mammoth hunter D'Leh (Steven Strait) has long ...
# 10  Cultural differences, past loves and personal ...
# 22  After being frightened by a peeping Tom at her...
#
#                                     critics_consensus content_rating  \
# 3   Sidney Lumet's feature debut is a superbly wri...             NR
# 4   One of Disney's finest live-action adventures,...              G
# 5   With attention strictly paid to style instead ...          PG-13
# 10                                                NaN             PG
# 22                                                NaN             PG
#
#                                       genres            director_x  \
# 3                            Classics, Drama          Sidney Lumet
# 4   Action & Adventure, Drama, Kids & Family     Richard Fleischer
# 5        Action & Adventure, Classics, Drama       Roland Emmerich
# 10                    Comedy, Drama, Romance  Adam Thomas Anderegg
# 22                 Drama, Mystery & Suspense          Joseph Losey
#
#                                        authors  \
# 3                                Reginald Rose
# 4                                  Earl Felton
# 5               Harald Kloser, Roland Emmerich
# 10        Jack Weyland, Janine Whetton Gilbert
# 22  Robert Thoeren, Hugo Butler, Dalton Trumbo
#
#                                              actors_x original_release_date  \
# 3   Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 4   James Mason, Kirk Douglas, Paul Lukas, Peter L...            1954-01-01
# 5   Steven Strait, Camilla Belle, Cliff Curtis, Jo...            2008-03-07
# 10  Heather Beers, Gary Neilson, Lisa McCammon, Ja...            2002-09-27
# 22  Van Heflin, Evelyn Keyes, Katherine Warren, Jo...            1951-12-03
#
#     ... actors_y  description avg_vote votes  budget  usa_gross_income  \
# 3   ...      NaN          NaN      NaN   NaN     NaN               NaN
# 4   ...      NaN          NaN      NaN   NaN     NaN               NaN
# 5   ...      NaN          NaN      NaN   NaN     NaN               NaN
# 10  ...      NaN          NaN      NaN   NaN     NaN               NaN
# 22  ...      NaN          NaN      NaN   NaN     NaN               NaN
#
#    worlwide_gross_income  metascore  reviews_from_users  reviews_from_critics
# 3                    NaN        NaN                 NaN                   NaN
# 4                    NaN        NaN                 NaN                   NaN
# 5                    NaN        NaN                 NaN                   NaN
# 10                   NaN        NaN                 NaN                   NaN
# 22                   NaN        NaN                 NaN                   NaN
#
# [5 rows x 45 columns]
